# %%
import os
import urllib.request

if not os.path.exists("the-verdixt.txt"):
    url = ("https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch02/01_main-chapter-code/the-verdict.txt")
    file_path = "the-verdixt.txt"
    urllib.request.urlretrieve(url, file_path)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import os
# ----> 2 import urlib.request
#       3
#       4 if not os.path.exists("the-verdixt.txt"):
#       5     url = ("https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch02/01_main-chapter-code/the-verdict.txt")
#
# ModuleNotFoundError: No module named 'urlib'
